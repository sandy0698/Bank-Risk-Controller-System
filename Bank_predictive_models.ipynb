# %%
# Import necessary libraries
import pandas as pd
from sklearn.metrics import mutual_info_score
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import scipy.stats as stats
from sklearn.metrics import mutual_info_score
from scipy.stats import pearsonr
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("E:/Final Project/loan_data.csv")

# %%
# Separate categorical and numerical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
df.dropna(subset=["OCCUPATION_TYPE"], inplace=True)

# %%
categorical_columns = df[['NAME_CONTRACT_TYPE_x', 'CODE_GENDER', 'FLAG_OWN_CAR',
       'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE_x', 'NAME_INCOME_TYPE',
       'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
       'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START_x', 'ORGANIZATION_TYPE',
       'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
       'EMERGENCYSTATE_MODE', 'NAME_CONTRACT_TYPE_y',
       'WEEKDAY_APPR_PROCESS_START_y', 'FLAG_LAST_APPL_PER_CONTRACT',
       'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE',
       'CODE_REJECT_REASON', 'NAME_TYPE_SUITE_y', 'NAME_CLIENT_TYPE',
       'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE',
       'CHANNEL_TYPE', 'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP',
       'PRODUCT_COMBINATION']]

# %%
for i in categorical_columns:
    df[i] = df[i].fillna(df[i].mode()[0])

# %%
categorical_nulls = df[categorical_cols].isnull().sum()
print("Categorical Null Values:")
print(categorical_nulls)
# Out:
# Categorical Null Values:
# NAME_CONTRACT_TYPE_x            0
# CODE_GENDER                     0
# FLAG_OWN_CAR                    0
# FLAG_OWN_REALTY                 0
# NAME_TYPE_SUITE_x               0
# NAME_INCOME_TYPE                0
# NAME_EDUCATION_TYPE             0
# NAME_FAMILY_STATUS              0
# NAME_HOUSING_TYPE               0
# OCCUPATION_TYPE                 0
# WEEKDAY_APPR_PROCESS_START_x    0
# ORGANIZATION_TYPE               0
# FONDKAPREMONT_MODE              0
# HOUSETYPE_MODE                  0
# WALLSMATERIAL_MODE              0
# EMERGENCYSTATE_MODE             0
# NAME_CONTRACT_TYPE_y            0
# WEEKDAY_APPR_PROCESS_START_y    0
# FLAG_LAST_APPL_PER_CONTRACT     0
# NAME_CASH_LOAN_PURPOSE          0
# NAME_CONTRACT_STATUS            0
# NAME_PAYMENT_TYPE               0
# CODE_REJECT_REASON              0
# NAME_TYPE_SUITE_y               0
# NAME_CLIENT_TYPE                0
# NAME_GOODS_CATEGORY             0
# NAME_PORTFOLIO                  0
# NAME_PRODUCT_TYPE               0
# CHANNEL_TYPE                    0
# NAME_SELLER_INDUSTRY            0
# NAME_YIELD_GROUP                0
# PRODUCT_COMBINATION             0
# dtype: int64

# %%
# Calculate Mutual Information for categorical features
mi_scores = []
for feature in categorical_cols:
    mi = mutual_info_score(df[feature], df['TARGET'])
    mi_scores.append(mi)
hybrid_scores = [0.5 * mi for mi in mi_scores]

# %%
ranked_categorical_features = [feature for _, feature in sorted(zip(mi_scores, categorical_cols), reverse=True)]
N = 10
selected_features = ranked_categorical_features[:N]
print("Selected Features:", selected_features)
# Out:
# Selected Features: ['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER', 'NAME_GOODS_CATEGORY']

# %%
df_1= df[['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER', 'NAME_GOODS_CATEGORY']]
df_1
# Out:
#         OCCUPATION_TYPE            NAME_EDUCATION_TYPE  \
# 0              Laborers  Secondary / secondary special
# 1            Core staff               Higher education
# 2            Core staff               Higher education
# 3            Core staff               Higher education
# 4              Laborers  Secondary / secondary special
# ...                 ...                            ...
# 1413696        Laborers               Higher education
# 1413697        Laborers               Higher education
# 1413698        Laborers               Higher education
# 1413699        Laborers               Higher education
# 1413700        Laborers               Higher education
#
#               ORGANIZATION_TYPE          PRODUCT_COMBINATION  \
# 0        Business Entity Type 3      POS other with interest
# 1                        School             Cash X-Sell: low
# 2                        School   POS industry with interest
# 3                        School  POS household with interest
# 4                    Government  POS mobile without interest
# ...                         ...                          ...
# 1413696  Business Entity Type 3          Cash X-Sell: middle
# 1413697  Business Entity Type 3                  Card Street
# 1413698  Business Entity Type 3             Cash Street: low
# 1413699  Business Entity Type 3             Cash X-Sell: low
# 1413700  Business Entity Type 3     POS mobile with interest
#
#         CODE_REJECT_REASON NAME_CONTRACT_STATUS      NAME_INCOME_TYPE  \
# 0                      XAP             Approved               Working
# 1                      XAP             Approved         State servant
# 2                      XAP             Approved         State servant
# 3                      XAP             Approved         State servant
# 4                      XAP             Approved               Working
# ...                    ...                  ...                   ...
# 1413696                XAP             Approved  Commercial associate
# 1413697                 HC              Refused  Commercial associate
# 1413698                 HC              Refused  Commercial associate
# 1413699                XAP             Approved  Commercial associate
# 1413700                XAP             Approved  Commercial associate
#
#         NAME_YIELD_GROUP CODE_GENDER   NAME_GOODS_CATEGORY
# 0             low_normal           M              Vehicles
# 1             low_normal           F                   XNA
# 2                 middle           F             Furniture
# 3                 middle           F  Consumer Electronics
# 4                 middle           M                Mobile
# ...                  ...         ...                   ...
# 1413696           middle           F                   XNA
# 1413697              XNA           F                   XNA
# 1413698       low_normal           F                   XNA
# 1413699       low_normal           F                   XNA
# 1413700             high           F             Computers
#
# [956121 rows x 10 columns]

# %%
df['NAME_YIELD_GROUP'].unique()
# Out:
# array(['low_normal', 'middle', 'XNA', 'high', 'low_action'], dtype=object)

# %%
selected_cat = df_1[['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER', 'NAME_GOODS_CATEGORY']]
nominal_variable = selected_cat[['OCCUPATION_TYPE','ORGANIZATION_TYPE','PRODUCT_COMBINATION','CODE_REJECT_REASON','NAME_GOODS_CATEGORY','CODE_GENDER']]
ordinal_variable = selected_cat[['NAME_EDUCATION_TYPE','NAME_CONTRACT_STATUS','NAME_INCOME_TYPE','NAME_YIELD_GROUP']]

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoder(datafarme,column):
  le = LabelEncoder()
  for feature in column:
    datafarme[feature] = le.fit_transform(df[feature])
  return datafarme
label_encoder(df_1,nominal_variable)
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
#          OCCUPATION_TYPE  NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0                      8                    4                  5
# 1                      3                    1                 39
# 2                      3                    1                 39
# 3                      3                    1                 39
# 4                      8                    4                 11
# ...                  ...                  ...                ...
# 1413696                8                    1                  5
# 1413697                8                    1                  5
# 1413698                8                    1                  5
# 1413699                8                    1                  5
# 1413700                8                    1                  5
#
#          PRODUCT_COMBINATION  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  \
# 0                         15                   7                     0
# 1                          7                   7                     0
# 2                         11                   7                     0
# 3                          9                   7                     0
# 4                         14                   7                     0
# ...                      ...                 ...                   ...
# 1413696                    8                   7                     0
# 1413697                    0                   1                     2
# 1413698                    4                   1                     2
# 1413699                    7                   7                     0
# 1413700                   13                   7                     0
#
#          NAME_INCOME_TYPE  NAME_YIELD_GROUP  CODE_GENDER  NAME_GOODS_CATEGORY
# 0                       5                 3            1                   24
# 1                       3                 3            0                   26
# 2                       3                 4            0                   11
# 3                       3                 4            0                    7
# 4                       5                 4            1                   18
# ...                   ...               ...          ...                  ...
# 1413696                 0                 4            0                   26
# 1413697                 0                 0            0                   26
# 1413698                 0                 3            0                   26
# 1413699                 0                 3            0                   26
# 1413700                 0                 1            0                    5
#
# [956121 rows x 10 columns]

# %%
label_encoder(df_1,ordinal_variable)
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\1412428131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
#          OCCUPATION_TYPE  NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0                      8                    4                  5
# 1                      3                    1                 39
# 2                      3                    1                 39
# 3                      3                    1                 39
# 4                      8                    4                 11
# ...                  ...                  ...                ...
# 1413696                8                    1                  5
# 1413697                8                    1                  5
# 1413698                8                    1                  5
# 1413699                8                    1                  5
# 1413700                8                    1                  5
#
#          PRODUCT_COMBINATION  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  \
# 0                         15                   7                     0
# 1                          7                   7                     0
# 2                         11                   7                     0
# 3                          9                   7                     0
# 4                         14                   7                     0
# ...                      ...                 ...                   ...
# 1413696                    8                   7                     0
# 1413697                    0                   1                     2
# 1413698                    4                   1                     2
# 1413699                    7                   7                     0
# 1413700                   13                   7                     0
#
#          NAME_INCOME_TYPE  NAME_YIELD_GROUP  CODE_GENDER  NAME_GOODS_CATEGORY
# 0                       5                 3            1                   24
# 1                       3                 3            0                   26
# 2                       3                 4            0                   11
# 3                       3                 4            0                    7
# 4                       5                 4            1                   18
# ...                   ...               ...          ...                  ...
# 1413696                 0                 4            0                   26
# 1413697                 0                 0            0                   26
# 1413698                 0                 3            0                   26
# 1413699                 0                 3            0                   26
# 1413700                 0                 1            0                    5
#
# [956121 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corrMatrix = df_1.corr()
plt.figure(figsize=(18, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
import scipy.stats as stats

# Initialize an empty dictionary to store p-values
p_values = {}

# Iterate over each pair of columns
for col1 in df_1.columns:
    for col2 in df_1.columns:
        if col1 != col2:  
            # Calculate correlation coefficient and p-value
            r, p = stats.pearsonr(df_1[col1], df_1[col2])
            # Store p-value in the dictionary
            p_values[(col1, col2)] = p

# Print p-values
print(p_values)
# Out:
# {('OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE'): 0.0, ('OCCUPATION_TYPE', 'ORGANIZATION_TYPE'): 0.0, ('OCCUPATION_TYPE', 'PRODUCT_COMBINATION'): 4.3016471968123606e-19, ('OCCUPATION_TYPE', 'CODE_REJECT_REASON'): 4.6321314996072464e-07, ('OCCUPATION_TYPE', 'NAME_CONTRACT_STATUS'): 1.3096376470933107e-14, ('OCCUPATION_TYPE', 'NAME_INCOME_TYPE'): 4.646486486766648e-31, ('OCCUPATION_TYPE', 'NAME_YIELD_GROUP'): 1.8547551541079407e-10, ('OCCUPATION_TYPE', 'CODE_GENDER'): 0.0, ('OCCUPATION_TYPE', 'NAME_GOODS_CATEGORY'): 3.9134191550781916e-14, ('NAME_EDUCATION_TYPE', 'OCCUPATION_TYPE'): 0.0, ('NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE'): 1.4920567736575736e-100, ('NAME_EDUCATION_TYPE', 'PRODUCT_COMBINATION'): 1.2539572149847437e-68, ('NAME_EDUCATION_TYPE', 'CODE_REJECT_REASON'): 2.6334515784623248e-17, ('NAME_EDUCATION_TYPE', 'NAME_CONTRACT_STATUS'): 5.64487165962891e-17, ('NAME_EDUCATION_TYPE', 'NAME_INCOME_TYPE'): 0.0, ('NAME_EDUCATION_TYPE', 'NAME_YIELD_GROUP'): 4.913042215432435e-19, ('NAME_EDUCATION_TYPE', 'CODE_GENDER'): 5.78204843100903e-294, ('NAME_EDUCATION_TYPE', 'NAME_GOODS_CATEGORY'): 1.1721780329262233e-56, ('ORGANIZATION_TYPE', 'OCCUPATION_TYPE'): 0.0, ('ORGANIZATION_TYPE', 'NAME_EDUCATION_TYPE'): 1.4920567736575736e-100, ('ORGANIZATION_TYPE', 'PRODUCT_COMBINATION'): 0.0020988048445710885, ('ORGANIZATION_TYPE', 'CODE_REJECT_REASON'): 2.2211752359878266e-10, ('ORGANIZATION_TYPE', 'NAME_CONTRACT_STATUS'): 1.302926763227272e-14, ('ORGANIZATION_TYPE', 'NAME_INCOME_TYPE'): 2.3389388616226213e-86, ('ORGANIZATION_TYPE', 'NAME_YIELD_GROUP'): 0.0032310514147047436, ('ORGANIZATION_TYPE', 'CODE_GENDER'): 0.0, ('ORGANIZATION_TYPE', 'NAME_GOODS_CATEGORY'): 0.1434237785796952, ('PRODUCT_COMBINATION', 'OCCUPATION_TYPE'): 4.3016471968123606e-19, ('PRODUCT_COMBINATION', 'NAME_EDUCATION_TYPE'): 1.2539572149847437e-68, ('PRODUCT_COMBINATION', 'ORGANIZATION_TYPE'): 0.0020988048445710885, ('PRODUCT_COMBINATION', 'CODE_REJECT_REASON'): 0.0, ('PRODUCT_COMBINATION', 'NAME_CONTRACT_STATUS'): 0.0, ('PRODUCT_COMBINATION', 'NAME_INCOME_TYPE'): 5.47762123478493e-224, ('PRODUCT_COMBINATION', 'NAME_YIELD_GROUP'): 0.0, ('PRODUCT_COMBINATION', 'CODE_GENDER'): 4.4986977226498424e-62, ('PRODUCT_COMBINATION', 'NAME_GOODS_CATEGORY'): 0.0, ('CODE_REJECT_REASON', 'OCCUPATION_TYPE'): 4.6321314996072464e-07, ('CODE_REJECT_REASON', 'NAME_EDUCATION_TYPE'): 2.6334515784623248e-17, ('CODE_REJECT_REASON', 'ORGANIZATION_TYPE'): 2.2211752359878266e-10, ('CODE_REJECT_REASON', 'PRODUCT_COMBINATION'): 0.0, ('CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS'): 0.0, ('CODE_REJECT_REASON', 'NAME_INCOME_TYPE'): 0.09169926729514634, ('CODE_REJECT_REASON', 'NAME_YIELD_GROUP'): 0.0, ('CODE_REJECT_REASON', 'CODE_GENDER'): 7.653907289416721e-07, ('CODE_REJECT_REASON', 'NAME_GOODS_CATEGORY'): 0.0, ('NAME_CONTRACT_STATUS', 'OCCUPATION_TYPE'): 1.3096376470933107e-14, ('NAME_CONTRACT_STATUS', 'NAME_EDUCATION_TYPE'): 5.64487165962891e-17, ('NAME_CONTRACT_STATUS', 'ORGANIZATION_TYPE'): 1.302926763227272e-14, ('NAME_CONTRACT_STATUS', 'PRODUCT_COMBINATION'): 0.0, ('NAME_CONTRACT_STATUS', 'CODE_REJECT_REASON'): 0.0, ('NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE'): 0.0012632254531838405, ('NAME_CONTRACT_STATUS', 'NAME_YIELD_GROUP'): 0.0, ('NAME_CONTRACT_STATUS', 'CODE_GENDER'): 2.6381115052696593e-19, ('NAME_CONTRACT_STATUS', 'NAME_GOODS_CATEGORY'): 0.0, ('NAME_INCOME_TYPE', 'OCCUPATION_TYPE'): 4.646486486766648e-31, ('NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE'): 0.0, ('NAME_INCOME_TYPE', 'ORGANIZATION_TYPE'): 2.3389388616226213e-86, ('NAME_INCOME_TYPE', 'PRODUCT_COMBINATION'): 5.47762123478493e-224, ('NAME_INCOME_TYPE', 'CODE_REJECT_REASON'): 0.09169926729514634, ('NAME_INCOME_TYPE', 'NAME_CONTRACT_STATUS'): 0.0012632254531838405, ('NAME_INCOME_TYPE', 'NAME_YIELD_GROUP'): 0.9069068922874653, ('NAME_INCOME_TYPE', 'CODE_GENDER'): 5.261900956317442e-41, ('NAME_INCOME_TYPE', 'NAME_GOODS_CATEGORY'): 5.820946125785915e-135, ('NAME_YIELD_GROUP', 'OCCUPATION_TYPE'): 1.8547551541079407e-10, ('NAME_YIELD_GROUP',  ...

# %%
print("\nNumerical Columns:")
print(numerical_cols)
# Out:
# Numerical Columns:
# Index(['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT_x', 'AMT_ANNUITY_x', 'AMT_GOODS_PRICE_x',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        ...
#        'RATE_INTEREST_PRIVILEGED', 'DAYS_DECISION', 'SELLERPLACE_AREA',
#        'CNT_PAYMENT', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE',
#        'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION',
#        'NFLAG_INSURED_ON_APPROVAL'],
#       dtype='object', length=126)

# %%
for i in numerical_cols:
    df[i] = df[i].fillna(df[i].mean())

# %%
numerical_nulls = df[numerical_cols].isnull().sum()
print(numerical_nulls)
# Out:
# SK_ID_CURR                   0
# TARGET                       0
# CNT_CHILDREN                 0
# AMT_INCOME_TOTAL             0
# AMT_CREDIT_x                 0
#                             ..
# DAYS_FIRST_DUE               0
# DAYS_LAST_DUE_1ST_VERSION    0
# DAYS_LAST_DUE                0
# DAYS_TERMINATION             0
# NFLAG_INSURED_ON_APPROVAL    0
# Length: 126, dtype: int64

# %%
corr_coeffs = []
for feature in numerical_cols:
    corr, _ = pearsonr(df[feature], df['TARGET'])
    corr_coeffs.append(corr)
# Out:
# C:\Users\santh\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
hybrid_scores = [0.5 * corr for corr in corr_coeffs]
# Rank categorical features by mutual information scores
ranked_continuous_features = [feature for _, feature in sorted(zip(corr_coeffs, numerical_cols), reverse=True)]
# Select top N features
N = 10
selected_features = ranked_continuous_features[:N]

print("Selected Features:", selected_features)
# Out:
# Selected Features: ['TARGET', 'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_DECISION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY']

# %%
df1 = df[['TARGET','AMT_INCOME_TOTAL','DAYS_BIRTH', 'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY', 'FLAG_EMP_PHONE', 'DAYS_REGISTRATION']]
df1['DAYS_BIRTH'] = df1['DAYS_BIRTH'].abs()  # making absolute values
df1["DAYS_LAST_PHONE_CHANGE"]=df1["DAYS_LAST_PHONE_CHANGE"].abs()
df1['DAYS_ID_PUBLISH'] = df1['DAYS_ID_PUBLISH'].abs()  # making absolute values
df1["DAYS_REGISTRATION"]=df1["DAYS_REGISTRATION"].abs()
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\2030636411.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DAYS_BIRTH'] = df1['DAYS_BIRTH'].abs()  # making absolute values
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\2030636411.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["DAYS_LAST_PHONE_CHANGE"]=df1["DAYS_LAST_PHONE_CHANGE"].abs()
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\2030636411.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DAYS_ID_PUBLISH'] = df1['DAYS_ID_PUBLISH'].abs()  # making absolute values
# C:\Users\santh\AppData\Local\Temp\ipykernel_27252\2030636411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["DAYS_REGISTRATION"]=df1["DAYS_REGISTRATION"].abs()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corrMatrix = df1.corr()
plt.figure(figsize=(18, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
import scipy.stats as stats

# Initialize an empty dictionary to store p-values
p_values = {}

# Iterate over each pair of columns
for col1 in df1.columns:
    for col2 in df1.columns:
        if col1 != col2:  # Avoid calculating correlation for the same column
            # Calculate correlation coefficient and p-value
            r, p = stats.pearsonr(df1[col1], df1[col2])
            # Store p-value in the dictionary
            p_values[(col1, col2)] = p

# Print p-values
print(p_values)
# Out:
# C:\Users\santh\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# C:\Users\santh\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# {('TARGET', 'AMT_INCOME_TOTAL'): 3.774790534831557e-05, ('TARGET', 'DAYS_BIRTH'): 0.0, ('TARGET', 'FLAG_MOBIL'): nan, ('TARGET', 'DAYS_LAST_PHONE_CHANGE'): 0.0, ('TARGET', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('TARGET', 'REGION_RATING_CLIENT'): 0.0, ('TARGET', 'DAYS_ID_PUBLISH'): 4.4946212418576824e-306, ('TARGET', 'REG_CITY_NOT_WORK_CITY'): 0.0, ('TARGET', 'FLAG_EMP_PHONE'): 0.3627144180407277, ('TARGET', 'DAYS_REGISTRATION'): 1.372646375866529e-291, ('AMT_INCOME_TOTAL', 'TARGET'): 3.774790534831557e-05, ('AMT_INCOME_TOTAL', 'DAYS_BIRTH'): 7.749939358772809e-187, ('AMT_INCOME_TOTAL', 'FLAG_MOBIL'): nan, ('AMT_INCOME_TOTAL', 'DAYS_LAST_PHONE_CHANGE'): 8.6945198538598e-105, ('AMT_INCOME_TOTAL', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('AMT_INCOME_TOTAL', 'REGION_RATING_CLIENT'): 0.0, ('AMT_INCOME_TOTAL', 'DAYS_ID_PUBLISH'): 3.740959447134317e-15, ('AMT_INCOME_TOTAL', 'REG_CITY_NOT_WORK_CITY'): 8.024484094182123e-20, ('AMT_INCOME_TOTAL', 'FLAG_EMP_PHONE'): 0.6036704167150055, ('AMT_INCOME_TOTAL', 'DAYS_REGISTRATION'): 5.0138616351772e-25, ('DAYS_BIRTH', 'TARGET'): 0.0, ('DAYS_BIRTH', 'AMT_INCOME_TOTAL'): 7.749939358772809e-187, ('DAYS_BIRTH', 'FLAG_MOBIL'): nan, ('DAYS_BIRTH', 'DAYS_LAST_PHONE_CHANGE'): 0.0, ('DAYS_BIRTH', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('DAYS_BIRTH', 'REGION_RATING_CLIENT'): 0.0, ('DAYS_BIRTH', 'DAYS_ID_PUBLISH'): 0.0, ('DAYS_BIRTH', 'REG_CITY_NOT_WORK_CITY'): 0.0, ('DAYS_BIRTH', 'FLAG_EMP_PHONE'): 0.0011481972939882496, ('DAYS_BIRTH', 'DAYS_REGISTRATION'): 0.0, ('FLAG_MOBIL', 'TARGET'): nan, ('FLAG_MOBIL', 'AMT_INCOME_TOTAL'): nan, ('FLAG_MOBIL', 'DAYS_BIRTH'): nan, ('FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE'): nan, ('FLAG_MOBIL', 'REGION_RATING_CLIENT_W_CITY'): nan, ('FLAG_MOBIL', 'REGION_RATING_CLIENT'): nan, ('FLAG_MOBIL', 'DAYS_ID_PUBLISH'): nan, ('FLAG_MOBIL', 'REG_CITY_NOT_WORK_CITY'): nan, ('FLAG_MOBIL', 'FLAG_EMP_PHONE'): nan, ('FLAG_MOBIL', 'DAYS_REGISTRATION'): nan, ('DAYS_LAST_PHONE_CHANGE', 'TARGET'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'AMT_INCOME_TOTAL'): 8.6945198538598e-105, ('DAYS_LAST_PHONE_CHANGE', 'DAYS_BIRTH'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'FLAG_MOBIL'): nan, ('DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY'): 1.2856719852522308e-235, ('DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT'): 1.418381737610526e-241, ('DAYS_LAST_PHONE_CHANGE', 'DAYS_ID_PUBLISH'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'REG_CITY_NOT_WORK_CITY'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'FLAG_EMP_PHONE'): 0.1004742370377749, ('DAYS_LAST_PHONE_CHANGE', 'DAYS_REGISTRATION'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'TARGET'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'AMT_INCOME_TOTAL'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_BIRTH'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'FLAG_MOBIL'): nan, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_LAST_PHONE_CHANGE'): 1.2856719852522308e-235, ('REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_ID_PUBLISH'): 3.017616126782492e-08, ('REGION_RATING_CLIENT_W_CITY', 'REG_CITY_NOT_WORK_CITY'): 1.7331213368868205e-215, ('REGION_RATING_CLIENT_W_CITY', 'FLAG_EMP_PHONE'): 0.6063128147244882, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_REGISTRATION'): 0.0, ('REGION_RATING_CLIENT', 'TARGET'): 0.0, ('REGION_RATING_CLIENT', 'AMT_INCOME_TOTAL'): 0.0, ('REGION_RATING_CLIENT', 'DAYS_BIRTH'): 0.0, ('REGION_RATING_CLIENT', 'FLAG_MOBIL'): nan, ('REGION_RATING_CLIENT', 'DAYS_LAST_PHONE_CHANGE'): 1.418381737610526e-241, ('REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH'): 3.348395012483691e-14, ('REGION_RATING_CLIENT', 'REG_CITY_NOT_WORK_CITY'): 9.074875971190758e-13, ('REGION_RATING_CLIENT', 'FLAG_EMP_PHONE'): 0.4028752865660181, ('REGION_RATING_CLIENT', 'DAYS_REGISTRATION'): 0.0, ('DAYS_ID_PUBLISH', 'TARGET'): 4.4946212418576824e-306, ('DAYS_ID_PUBLISH', 'AMT_INCOME_TOTAL'): 3.740959447134317e-15, ('DAYS_ID_PUBLISH', 'DAYS_BIRTH'): 0.0, ('DAYS_ID_PUBLISH', 'FLAG_MOBIL'): nan, ('DAYS_ID_PUBLISH', 'DAYS_LAST_PHONE_CHANGE'): 0.0, ( ...

# %%
df_modified = pd.concat([df_1,df1],axis=1)

# %%
df_modified
# Out:
#          OCCUPATION_TYPE  NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0                      8                    4                  5
# 1                      3                    1                 39
# 2                      3                    1                 39
# 3                      3                    1                 39
# 4                      8                    4                 11
# ...                  ...                  ...                ...
# 1413696                8                    1                  5
# 1413697                8                    1                  5
# 1413698                8                    1                  5
# 1413699                8                    1                  5
# 1413700                8                    1                  5
#
#          PRODUCT_COMBINATION  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  \
# 0                         15                   7                     0
# 1                          7                   7                     0
# 2                         11                   7                     0
# 3                          9                   7                     0
# 4                         14                   7                     0
# ...                      ...                 ...                   ...
# 1413696                    8                   7                     0
# 1413697                    0                   1                     2
# 1413698                    4                   1                     2
# 1413699                    7                   7                     0
# 1413700                   13                   7                     0
#
#          NAME_INCOME_TYPE  NAME_YIELD_GROUP  CODE_GENDER  NAME_GOODS_CATEGORY  \
# 0                       5                 3            1                   24
# 1                       3                 3            0                   26
# 2                       3                 4            0                   11
# 3                       3                 4            0                    7
# 4                       5                 4            1                   18
# ...                   ...               ...          ...                  ...
# 1413696                 0                 4            0                   26
# 1413697                 0                 0            0                   26
# 1413698                 0                 3            0                   26
# 1413699                 0                 3            0                   26
# 1413700                 0                 1            0                    5
#
#          ...  AMT_INCOME_TOTAL  DAYS_BIRTH  FLAG_MOBIL  \
# 0        ...          202500.0        9461           1
# 1        ...          270000.0       16765           1
# 2        ...          270000.0       16765           1
# 3        ...          270000.0       16765           1
# 4        ...           67500.0       19046           1
# ...      ...               ...         ...         ...
# 1413696  ...          157500.0       16856           1
# 1413697  ...          157500.0       16856           1
# 1413698  ...          157500.0       16856           1
# 1413699  ...          157500.0       16856           1
# 1413700  ...          157500.0       16856           1
#
#          DAYS_LAST_PHONE_CHANGE  REGION_RATING_CLIENT_W_CITY  \
# 0                        1134.0                            2
# 1                         828.0                            1
# 2                         828.0                            1
# 3                         828.0                            1
# 4                         815.0                            2
# ...                         ...                          ...
# 1413696                   787.0                            1
# 1413697                   787.0                            1
# 1413698                   787.0                            1
# 1413699                   787.0                            1
# 1413700                   787.0                            1
#
#          REGION_RATING_CLIENT  DAYS_ID_PUBLISH  REG_CITY_NOT_WORK_CITY  \
# 0                           2             2120                       0
# 1                           1              291                       0
# 2                           1              291                       0
# 3                           1              291                       0
# 4                           2             2531                       0
# ...                       ...              ...                     ...
# 1413696                     1              410                       1
# 1413697                     1              410                       1
# 1413698                     1              410                       1
# 1413699                     1              410                       1
# 1413700                     1              410                       1
#
#          FLAG_EMP_PHONE  DAYS_REGISTRATION
# 0                     1             3648.0
# 1                     1             1186.0
# 2                     1             1186.0
# 3                     1             1186.0
# 4                     1             4260.0
# ...                 ...                ...
# 1413696               1             5128.0
# 1413697               1             5128.0
# 1413698               1             5128.0
# 1413699               1             5128.0
# 1413700               1             5128.0
#
# [956121 rows x 21 columns]

# %%
def skewplot(df, column):
    plt.figure(figsize=(10, 4))

    # Boxplot
    plt.subplot(1, 3, 2)
    sns.boxplot(df[column])
    plt.title("Box plot for " + column)
    plt.tight_layout()
    plt.show()
df_modified.columns
# Out:
# Index(['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
#        'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
#        'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
#        'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
#        'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
#        'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
#        'FLAG_EMP_PHONE', 'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
#        'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
#        'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
#        'AMT_INCOME_TOTAL_log', 'DAYS_LAST_PHONE_CHANGE_log',
#        'DAYS_ID_PUBLISH_log', 'DAYS_REGISTRATION_log'],
#       dtype='object')

# %%
df_modified['DAYS_REGISTRATION'].unique()
# Out:
# array([ 3648.,  1186.,  4260., ..., 12316., 14083., 12372.])

# %%
skewed_columns= ['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
       'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
       'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
       'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
       'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
       'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
       'FLAG_EMP_PHONE', 'DAYS_REGISTRATION']
 

for column in skewed_columns:
    skewplot(df_modified, column)

# %%
import numpy as np

# Apply square root transformation to the specified columns


df_modified['NAME_EDUCATION_TYPE_log'] = np.log(df_modified['NAME_EDUCATION_TYPE'])
df_modified["PRODUCT_COMBINATION_log"] = np.log(df_modified["PRODUCT_COMBINATION"])
df_modified["CODE_REJECT_REASON_log"] = np.log(df_modified["CODE_REJECT_REASON"])
df_modified["NAME_INCOME_TYPE_log"] = np.log(df_modified["NAME_INCOME_TYPE"])
df_modified["NAME_GOODS_CATEGORY_log"] = np.log(df_modified["NAME_GOODS_CATEGORY"])
df_modified["AMT_INCOME_TOTAL_log"] = np.log(df_modified["AMT_INCOME_TOTAL"])
df_modified["DAYS_LAST_PHONE_CHANGE_log"] = np.log(df_modified["DAYS_LAST_PHONE_CHANGE"])
df_modified["DAYS_ID_PUBLISH_log"] = np.log(df_modified["DAYS_ID_PUBLISH"])
df_modified["DAYS_REGISTRATION_log"] = np.log(df_modified["DAYS_REGISTRATION"])
# Out:
# C:\Users\santh\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_modified.columns
# Out:
# Index(['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
#        'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
#        'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
#        'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
#        'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
#        'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
#        'FLAG_EMP_PHONE', 'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
#        'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
#        'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
#        'AMT_INCOME_TOTAL_log', 'DAYS_LAST_PHONE_CHANGE_log',
#        'DAYS_ID_PUBLISH_log', 'DAYS_REGISTRATION_log'],
#       dtype='object')

# %%
log_column = ['NAME_EDUCATION_TYPE_log','PRODUCT_COMBINATION_log','CODE_REJECT_REASON_log',
              'NAME_INCOME_TYPE_log','NAME_GOODS_CATEGORY_log','AMT_INCOME_TOTAL_log',
              'DAYS_LAST_PHONE_CHANGE_log','DAYS_ID_PUBLISH_log','DAYS_REGISTRATION_log']
for i in log_column:
  skewplot(df_modified,i)
# Out:
# C:\Users\santh\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
df_modified[['NAME_EDUCATION_TYPE_log']]
# Out:
#          NAME_EDUCATION_TYPE_log
# 0                       1.386294
# 1                       0.000000
# 2                       0.000000
# 3                       0.000000
# 4                       1.386294
# ...                          ...
# 1413696                 0.000000
# 1413697                 0.000000
# 1413698                 0.000000
# 1413699                 0.000000
# 1413700                 0.000000
#
# [956121 rows x 1 columns]

# %%
def outlier(df,column):
  q1= df[column].quantile(0.25)
  q3= df[column].quantile(0.75)
  iqr= q3-q1

  upper_threshold= q3 + (1.5*iqr)
  lower_threshold= q1 - (1.5*iqr)

  df[column]= df[column].clip(lower_threshold, upper_threshold)

# %%
outlier_columns= ['CODE_REJECT_REASON','NAME_GOODS_CATEGORY','NAME_INCOME_TYPE','AMT_INCOME_TOTAL','DAYS_LAST_PHONE_CHANGE','DAYS_ID_PUBLISH','DAYS_REGISTRATION']

for i in outlier_columns:
  outlier(df_modified,i)

# %%
for i in outlier_columns:
  skewplot(df_modified,i)

# %%
df_modified[['DAYS_REGISTRATION','TARGET']]
# Out:
#          DAYS_REGISTRATION  TARGET
# 0                   3648.0       1
# 1                   1186.0       0
# 2                   1186.0       0
# 3                   1186.0       0
# 4                   4260.0       0
# ...                    ...     ...
# 1413696             5128.0       0
# 1413697             5128.0       0
# 1413698             5128.0       0
# 1413699             5128.0       0
# 1413700             5128.0       0
#
# [956121 rows x 2 columns]

# %%
df_modified_1 = df_modified.copy()

# %%
df_modified_1.to_csv(r"E:/Final Project/df_new.csv")

# %%
df_2 = pd.read_csv("E:/Final Project/df_new.csv")

# %%
df_2['AGE'] = df_2['DAYS_BIRTH'] / -365
df_2['AGE'] = df_2['AGE'].abs()
df_2['AGE'].isnull().sum()
# Out:
# 0

# %%
df_2['INCOME_PA'] = df_2['AMT_INCOME_TOTAL']*12

# %%
# Group by income_type and income_percentile_bin
grouped_df = df_2.groupby(['NAME_INCOME_TYPE', 'INCOME_PA']).size().reset_index(name='count')

# Print the grouped data
print(grouped_df)
# Out:
#       NAME_INCOME_TYPE  INCOME_PA  count
# 0                    0   318600.0      2
# 1                    0   324000.0      4
# 2                    0   351000.0      1
# 3                    0   378000.0     27
# 4                    0   405000.0      1
# ...                ...        ...    ...
# 1758                 5  4590000.0   1730
# 1759                 5  4637682.0     21
# 1760                 5  4644000.0    195
# 1761                 5  4698000.0    143
# 1762                 5  4725000.0  11172
#
# [1763 rows x 3 columns]

# %%
grouped_df.max()
# Out:
# NAME_INCOME_TYPE          5.0
# INCOME_PA           4725000.0
# count                 75818.0
# dtype: float64

# %%
df_2['INCOME_PA'].max()
# Out:
# 4725000.0

# %%
df_2['CLIENT_RATING'] = pd.cut(df_2['REGION_RATING_CLIENT_W_CITY'], bins=[0,1,2,3], labels=['Low', 'Medium', 'High'])
df_2['CLIENT_RATING_W_CITY'] =  df_2['CLIENT_RATING'].map({'Low': 1, 'Medium': 2, 'High': 3})
df_2['DAYS_LAST_PHONE_CHANGE_log'].unique()
df_2['CLIENT_RATING_W_CITY'].unique()
# Out:
# [2, 1, 3]
# Categories (3, int64): [1 < 2 < 3]

# %%
df_2['CLIENT_RATING_W_CITY'] = df_2['CLIENT_RATING_W_CITY'].astype(int)
df_2['AGE'] = df_2['AGE'].astype(int)
df_2.columns
# Out:
# Index(['Unnamed: 0', 'OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE',
#        'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON',
#        'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP',
#        'CODE_GENDER', 'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL',
#        'DAYS_BIRTH', 'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE',
#        'REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT',
#        'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY', 'FLAG_EMP_PHONE',
#        'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
#        'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
#        'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
#        'AMT_INCOME_TOTAL_log', 'DAYS_LAST_PHONE_CHANGE_log',
#        'DAYS_ID_PUBLISH_log', 'DAYS_REGISTRATION_log', 'AGE', 'INCOME_PA',
#        'CLIENT_RATING', 'CLIENT_RATING_W_CITY'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ddff = df_2[['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
       'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
       'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
       'NAME_GOODS_CATEGORY', 'TARGET', 'AGE', 'INCOME_PA',
       'CLIENT_RATING_W_CITY','FLAG_MOBIL',
       'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
       'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
       'FLAG_EMP_PHONE', 'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
       'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
       'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
       'DAYS_LAST_PHONE_CHANGE_log', 'DAYS_ID_PUBLISH_log',
       'DAYS_REGISTRATION_log']]

# Calculate the correlation matrix
corr = ddff.corr()

# Plot the heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(corr, annot=True, fmt=".2f",cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\santh\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
#Avoiding high corr features- NAME_CONTRACT_STATUS and CODE_REJECT_REASON REGION_RATING_CLIENT and REGION_RATING_CLIENT_W_CITY FLAG_MOBIL and DAYS_LAST_PHONE_CHANGE DAYS_ID_PUBLISH and REG_CITY_NOT_WORK_CITY

final_data = df_2[['TARGET','OCCUPATION_TYPE','NAME_EDUCATION_TYPE',
                   'NAME_INCOME_TYPE','INCOME_PA','CODE_REJECT_REASON',
                   'NAME_CONTRACT_STATUS','NAME_YIELD_GROUP',
                    'CODE_GENDER','AGE','CLIENT_RATING_W_CITY',
                    'DAYS_LAST_PHONE_CHANGE_log', 'DAYS_ID_PUBLISH_log',
                    'DAYS_REGISTRATION_log']]

# %%
final_data
# Out:
#         TARGET  OCCUPATION_TYPE  NAME_EDUCATION_TYPE  NAME_INCOME_TYPE  \
# 0            1                8                    4                 5
# 1            0                3                    1                 3
# 2            0                3                    1                 3
# 3            0                3                    1                 3
# 4            0                8                    4                 5
# ...        ...              ...                  ...               ...
# 956116       0                8                    1                 0
# 956117       0                8                    1                 0
# 956118       0                8                    1                 0
# 956119       0                8                    1                 0
# 956120       0                8                    1                 0
#
#         INCOME_PA  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  NAME_YIELD_GROUP  \
# 0       2430000.0                   7                     0                 3
# 1       3240000.0                   7                     0                 3
# 2       3240000.0                   7                     0                 4
# 3       3240000.0                   7                     0                 4
# 4        810000.0                   7                     0                 4
# ...           ...                 ...                   ...               ...
# 956116  1890000.0                   7                     0                 4
# 956117  1890000.0                   7                     2                 0
# 956118  1890000.0                   7                     2                 3
# 956119  1890000.0                   7                     0                 3
# 956120  1890000.0                   7                     0                 1
#
#         CODE_GENDER  AGE  CLIENT_RATING_W_CITY  DAYS_LAST_PHONE_CHANGE_log  \
# 0                 1   25                     2                    7.033506
# 1                 0   45                     1                    6.719013
# 2                 0   45                     1                    6.719013
# 3                 0   45                     1                    6.719013
# 4                 1   52                     2                    6.703188
# ...             ...  ...                   ...                         ...
# 956116            0   46                     1                    6.668228
# 956117            0   46                     1                    6.668228
# 956118            0   46                     1                    6.668228
# 956119            0   46                     1                    6.668228
# 956120            0   46                     1                    6.668228
#
#         DAYS_ID_PUBLISH_log  DAYS_REGISTRATION_log
# 0                  7.659171               8.201934
# 1                  5.673323               7.078342
# 2                  5.673323               7.078342
# 3                  5.673323               7.078342
# 4                  7.836370               8.357024
# ...                     ...                    ...
# 956116             6.016157               8.542471
# 956117             6.016157               8.542471
# 956118             6.016157               8.542471
# 956119             6.016157               8.542471
# 956120             6.016157               8.542471
#
# [956121 rows x 14 columns]

# %%
final_data['TARGET'].value_counts()
# Out:
# TARGET
# 0    865635
# 1     90486
# Name: count, dtype: int64

# %%
#train test split


from sklearn.model_selection import train_test_split


from imblearn.over_sampling import RandomOverSampler

ro = RandomOverSampler(random_state= 46)

features = final_data.drop('TARGET',axis=1)
target = final_data['TARGET']

re_data, re_tar = ro.fit_resample(features, target)
re_data['TARGET'] = re_tar 

val = re_data.drop('TARGET', axis=1)
tar = re_data['TARGET']

X_train, X_test, y_train, y_test  = train_test_split(val, tar, test_size= 0.2, random_state=46)

X_train = X_train.clip(lower=-1e10, upper=1e10)
X_test = X_test.clip(lower=-1e10, upper=1e10)


print("Training data shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

print("Testing data shapes:")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# Training data shapes:
# X_train: (1385016, 13)
# y_train: (1385016,)
# Testing data shapes:
# X_test: (346254, 13)
# y_test: (346254,)

# %%
#KNNeighbors

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler0 = StandardScaler()
X1_train_scaled = scaler0.fit_transform(X_train)
X1_test_scaled = scaler0.transform(X_test)


knn = KNeighborsClassifier(n_neighbors=9)

# Fit the classifier
knn.fit(X1_train_scaled, y_train)

# Predict the labels
y_pred = knn.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.8622398586009115
# Confusion Matrix:
# [[130294  42934]
#  [  4766 168260]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[130294  42934]
#  [  4766 168260]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.75      0.85    173228
#            1       0.80      0.97      0.88    173026
#
#     accuracy                           0.86    346254
#    macro avg       0.88      0.86      0.86    346254
# weighted avg       0.88      0.86      0.86    346254

# %%
#DecisionTree

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler


scaler1 = StandardScaler()
X1_train_scaled = scaler1.fit_transform(X_train)
X1_test_scaled = scaler1.transform(X_test)

Decison_tree = DecisionTreeClassifier(
    criterion='gini',
    max_depth=30,
    min_samples_split=6,
    min_samples_leaf=6
)

# Fit the classifier
Decison_tree.fit(X1_train_scaled, y_train)

# Predict the labels
y_pred = Decison_tree.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.856908512248234
# Confusion Matrix:
# [[136810  36418]
#  [ 13128 159898]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')                                           #  DECISON TREE
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[136810  36418]
#  [ 13128 159898]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85    173228
#            1       0.81      0.92      0.87    173026
#
#     accuracy                           0.86    346254
#    macro avg       0.86      0.86      0.86    346254
# weighted avg       0.86      0.86      0.86    346254

# %%
from sklearn.ensemble import RandomForestClassifier    # random forest
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler2 = StandardScaler()
X1_train_scaled = scaler2.fit_transform(X_train)
X1_test_scaled = scaler2.transform(X_test)

random_forest = RandomForestClassifier(
    n_estimators=350,
    max_depth=20,
    min_samples_split=16,
    min_samples_leaf=9,
    criterion='gini',
    max_features='sqrt'
)

# Fit
random_forest.fit(X1_train_scaled, y_train)

# Predict
y_pred_rf = random_forest.predict(X1_test_scaled)

# Evaluate the classifier
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Accuracy: {accuracy_rf}")
cm_rf = confusion_matrix(y_test, y_pred_rf)
print(f"Confusion Matrix:\n{cm_rf}")
# Out:
# Accuracy: 0.777510151507275
# Confusion Matrix:
# [[127610  45618]
#  [ 31420 141606]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[136810  36418]
#  [ 13128 159898]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85    173228
#            1       0.81      0.92      0.87    173026
#
#     accuracy                           0.86    346254
#    macro avg       0.86      0.86      0.86    346254
# weighted avg       0.86      0.86      0.86    346254

# %%
from xgboost import XGBClassifier   # xgb
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler3 = StandardScaler()
X1_train_scaled = scaler3.fit_transform(X_train)
X1_test_scaled = scaler3.transform(X_test)

xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss',
                    n_estimators=750,
                    max_depth=9,
                    learning_rate=0.5,
                    subsample=0.9,
                    colsample_bytree=0.9)

# Fit
xgb.fit(X1_train_scaled, y_train)

# Predict
y_pred = xgb.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# C:\Users\santh\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [08:28:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy: 0.9838240135854026
# Confusion Matrix:
# [[168694   4534]
#  [  1067 171959]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))

false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[168694   4534]
#  [  1067 171959]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98    173228
#            1       0.97      0.99      0.98    173026
#
#     accuracy                           0.98    346254
#    macro avg       0.98      0.98      0.98    346254
# weighted avg       0.98      0.98      0.98    346254

# %%
final_data['TARGET'].value_counts()
# Out:
# TARGET
# 0    865635
# 1     90486
# Name: count, dtype: int64

# %%
sample = np.array([[8,4,5,2430000,7,0,3,1,25,2,np.log(1134.0),np.log(2120),np.log(3648.0)]])
pred = xgb.predict(sample)
if pred==1:
    print('The status is: Wont Repay')
else:
    print('The status is: Repay')
# Out:
# The status is: Wont Repay

# %%
# Saving the model
import pickle
with open('knnmodel_1.pkl', 'wb') as file:
    pickle.dump(knn, file)


with open('dtmodel_1.pkl', 'wb') as file:
    pickle.dump(Decison_tree, file)

with open('rfmodel_1.pkl', 'wb') as file:
    pickle.dump(random_forest, file)

with open('xgbmodel_1.pkl', 'wb') as file:
    pickle.dump(xgb, file)

# %%
with open('xgbmodel_1.pkl', 'wb') as file:
    pickle.dump(xgb, file)
